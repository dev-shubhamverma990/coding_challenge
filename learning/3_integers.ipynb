# %%
import sys

# %%
myvalue = 32
print(f"Integeer size: {sys.getsizeof(myvalue)} bytes")

# %%
"""in python integerss are the object of the class which also has its methods, to store these methos it takes relative
more memory than other language.
Based on the integre size, it memory allocation also increases as the value increases, for example if we assign 1000
 to myvalue then it will take more memory than 32 because of the size of the integer."""

# %%
"floor and ceil"

# %%
"Integrer Bases"
my_decimal = int("42", base=10)
my_decimal = int("42", base=16)
my_decimal = int("101101", base=2)
my_decimal = int("dd223", base=0)
